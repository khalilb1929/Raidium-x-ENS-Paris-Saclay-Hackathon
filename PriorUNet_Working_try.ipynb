# %% [markdown]
# # 🎯 Prior-Enhanced UNet - Few-Shot Learning
# Simplified, working implementation with visible predictions

# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib.pyplot as plt
from pathlib import Path
from tqdm import tqdm
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

print("✅ All imports successful")
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")
# Out:
# ✅ All imports successful
# Using device: cpu

# %%
# Load labels FIRST to know which indices have labels
print("Loading labels...")
labels_df = pd.read_csv('y_train.csv', index_col=0).T
# Image IDs are in the INDEX (rows), not columns
labels_available_indices = sorted([int(idx) for idx in labels_df.index])
print(f"Labels available for {len(labels_available_indices)} images: {labels_available_indices[:20]}...")

# Load ONLY images that have corresponding labels
print("Loading images...")
image_dir = Path('train-images')
available_images = sorted([int(p.stem) for p in image_dir.glob('*.png')])

# Filter to keep only images with labels
images_with_labels = [idx for idx in available_images if idx in labels_df.index]
print(f"Found {len(images_with_labels)} images with labels out of {len(available_images)} total")

images_list = []
labels_2d_list = []
image_ids_mapping = []  # Keep track of true image IDs

for idx in tqdm(images_with_labels, desc='Loading matched images'):
    img = cv2.imread(str(image_dir / f'{idx}.png'), cv2.IMREAD_GRAYSCALE)
    if img is not None:
        images_list.append(img.astype(np.float32))  # Keep [0, 255] for preprocessing
        label = labels_df.loc[idx].values.reshape(256, 256).astype(np.uint8)
        labels_2d_list.append(label)
        image_ids_mapping.append(idx)  # Store the true image ID

images_np = np.array(images_list)
labels_2d = np.array(labels_2d_list)
image_ids_mapping = np.array(image_ids_mapping)  # Convert to numpy array for easy access

print(f"\n✅ Data loaded and aligned!")
print(f"Images: {images_np.shape}, dtype: {images_np.dtype}")
print(f"Labels: {labels_2d.shape}, dtype: {labels_2d.dtype}")
print(f"Image ID mapping: {image_ids_mapping}")
print(f"Classes: {len(np.unique(labels_2d))}")
# Out:
# Loading labels...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 5
#       3 labels_df = pd.read_csv('y_train.csv', index_col=0).T
#       4 # Image IDs are in the INDEX (rows), not columns
# ----> 5 labels_available_indices = sorted([int(idx) for idx in labels_df.index])
#       6 print(f"Labels available for {len(labels_available_indices)} images: {labels_available_indices[:20]}...")
#       8 # Load ONLY images that have corresponding labels
#
# Cell In[36], line 5, in <listcomp>(.0)
#       3 labels_df = pd.read_csv('y_train.csv', index_col=0).T
#       4 # Image IDs are in the INDEX (rows), not columns
# ----> 5 labels_available_indices = sorted([int(idx) for idx in labels_df.index])
#       6 print(f"Labels available for {len(labels_available_indices)} images: {labels_available_indices[:20]}...")
#       8 # Load ONLY images that have corresponding labels
#
# ValueError: invalid literal for int() with base 10: '0.png'

# %%
# Image Preprocessing: Normalization, Smoothing, Clipping
print("\n📊 Applying preprocessing to images...")

# Preprocessing function
def preprocess_image(img, smooth_kernel=3, clip_percentile=1):
    """
    Preprocess image:
    - Normalize to [0, 1]
    - Gaussian smoothing to reduce noise
    - Clip extreme values (outliers)
    """
    # 1. Normalize to [0, 1]
    img_norm = img / 255.0
    img_norm = np.clip(img_norm, 0, 1).astype(np.float32)
    
    # 2. Gaussian smoothing (reduce noise)
    img_smooth = cv2.GaussianBlur(img_norm, (smooth_kernel, smooth_kernel), 0)
    
    # 3. Clip outliers (remove extreme values)
    low_percentile = np.percentile(img_smooth, clip_percentile)
    high_percentile = np.percentile(img_smooth, 100 - clip_percentile)
    img_clipped = np.clip(img_smooth, low_percentile, high_percentile)
    
    # Re-normalize after clipping
    img_clipped = (img_clipped - img_clipped.min()) / (img_clipped.max() - img_clipped.min() + 1e-8)
    
    return img_clipped.astype(np.float32)

# Apply preprocessing to all images
images_np_processed = np.array([preprocess_image(img) for img in images_np])

# Replace original with processed
images_np = images_np_processed

print(f"✅ Preprocessing complete!")
print(f"   Images normalized to [0, 1]")
print(f"   Gaussian smoothing applied (kernel={5})")
print(f"   Outliers clipped (percentile={1}%)")
print(f"   Final shape: {images_np.shape}")
print(f"   Value range: [{images_np.min():.4f}, {images_np.max():.4f}]")
# Out:
# 📊 Applying preprocessing to images...
# ✅ Preprocessing complete!
#    Images normalized to [0, 1]
#    Gaussian smoothing applied (kernel=5)
#    Outliers clipped (percentile=1%)
#    Final shape: (1358, 256, 256)
#    Value range: [0.0000, 1.0000]

# %%
# Check actual number of classes
print(f"\n📊 Class Analysis:")
unique_classes = np.unique(labels_2d)
print(f"Unique classes in data: {len(unique_classes)}")
print(f"Class range: {unique_classes.min()} to {unique_classes.max()}")
print(f"Classes: {sorted(unique_classes)[:20]}...")  # Show first 20

# Class distribution
class_dist = np.bincount(labels_2d.flatten())
print(f"\nClass frequency distribution:")
for cls_id, count in enumerate(class_dist):
    if count > 0:
        pct = 100 * count / labels_2d.size
        print(f"  Class {cls_id}: {count:6d} pixels ({pct:5.2f}%)")
# Out:
# 📊 Class Analysis:
# Unique classes in data: 55
# Class range: 0 to 54
# Classes: [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19)]...
#
# Class frequency distribution:
#   Class 0: 83046868 pixels (93.31%)
#   Class 1:    926 pixels ( 0.00%)
#   Class 2:    673 pixels ( 0.00%)
#   Class 3: 115092 pixels ( 0.13%)
#   Class 4: 208579 pixels ( 0.23%)
#   Class 5: 201305 pixels ( 0.23%)
#   Class 6: 283963 pixels ( 0.32%)
#   Class 7:   4723 pixels ( 0.01%)
#   Class 8:   4422 pixels ( 0.00%)
#   Class 9: 247582 pixels ( 0.28%)
#   Class 10:  19671 pixels ( 0.02%)
#   Class 11:  17542 pixels ( 0.02%)
#   Class 12: 320273 pixels ( 0.36%)
#   Class 13:   7937 pixels ( 0.01%)
#   Class 14:   6131 pixels ( 0.01%)
#   Class 15:   7501 pixels ( 0.01%)
#   Class 16:  65158 pixels ( 0.07%)
#   Class 17:  55008 pixels ( 0.06%)
#   Class 18:  63491 pixels ( 0.07%)
#   Class 19:  68319 pixels ( 0.08%)
#   Class 20:  11931 pixels ( 0.01%)
#   Class 21:  14037 pixels ( 0.02%)
#   Class 22: 330252 pixels ( 0.37%)
#   Class 23:  90404 pixels ( 0.10%)
#   Class 24:  76409 pixels ( 0.09%)
#   Class 25:   1977 pixels ( 0.00%)
#   Class 26:   1859 pixels ( 0.00%)
#   Class 27:   4612 pixels ( 0.01%)
#   Class 28:   5045 pixels ( 0.01%)
#   Class 29:   9206 pixels ( 0.01%)
#   Class 30:   6423 pixels ( 0.01%)
#   Class 31:  87612 pixels ( 0.10%)
#   Class 32:  86498 pixels ( 0.10%)
#   Class 33:  28015 pixels ( 0.03%)
#   Class 34:  47374 pixels ( 0.05%)
#   Class 35:  55493 pixels ( 0.06%)
#   Class 36: 550923 pixels ( 0.62%)
#   Class 37: 781124 pixels ( 0.88%)
#   Class 38: 925175 pixels ( 1.04%)
#   Class 39:  20693 pixels ( 0.02%)
#   Class 40:   5564 pixels ( 0.01%)
#   Class 41:  36685 pixels ( 0.04%)
#   Class 42:  53261 pixels ( 0.06%)
#   Class 43:  50937 pixels ( 0.06%)
#   Class 44:  76503 pixels ( 0.09%)
#   Class 45:  17677 pixels ( 0.02%)
#   Class 46:  14275 pixels ( 0.02%)
#   Class 47: 315423 pixels ( 0.35%)
#   Class 48:  72506 pixels ( 0.08%)
#   Class 49: 111266 pixels ( 0.13%)
#   Class 50:  13885 pixels ( 0.02%)
#   Class 51:  28022 pixels ( 0.03%)
#   Class 52:  51741 pixels ( 0.06%)
#   Class 53: 110911 pixels ( 0.12%)
#   Class 54: 159006 pixels ( 0.18%)

# %%
# Enhanced Prior generator with multi-scale features
class PriorGenerator:
    @staticmethod
    def get_prior(image):
        """Create multi-scale priors: intensity + edges + texture"""
        # Normalize
        img_norm = image / (image.max() + 1e-8)
        
        # Sobel edges (multi-scale)
        sx = cv2.Sobel(img_norm, cv2.CV_32F, 1, 0, ksize=3)
        sy = cv2.Sobel(img_norm, cv2.CV_32F, 0, 1, ksize=3)
        edges = np.sqrt(sx**2 + sy**2)
        edges = edges / (edges.max() + 1e-8)
        
        # Laplacian (texture/corners)
        laplacian = cv2.Laplacian(img_norm, cv2.CV_32F)
        laplacian = np.abs(laplacian)
        laplacian = laplacian / (laplacian.max() + 1e-8)
        
        # Return 3-channel prior: [intensity, edges, texture]
        return np.stack([img_norm, edges, laplacian], axis=0).astype(np.float32)

prior_gen = PriorGenerator()
print("✅ Enhanced prior generator ready (3 channels)")
# Out:
# ✅ Enhanced prior generator ready (3 channels)

# %%
# Prior-Enhanced UNet with Dropout
NUM_CLASSES = len(np.unique(labels_2d))  # Use actual number of classes
print(f"🎯 Configuring model for {NUM_CLASSES} classes")

class PriorUNet(nn.Module):
    def __init__(self, num_classes=NUM_CLASSES, dropout_rate=0.3):
        super().__init__()
        
        c = 32  # base channels
        
        # Encoder
        self.enc1 = nn.Sequential(
            nn.Conv2d(4, c, 3, padding=1), nn.BatchNorm2d(c), nn.ReLU(inplace=True), nn.Dropout2d(dropout_rate),
            nn.Conv2d(c, c, 3, padding=1), nn.BatchNorm2d(c), nn.ReLU(inplace=True)
        )
        self.pool1 = nn.MaxPool2d(2)
        
        self.enc2 = nn.Sequential(
            nn.Conv2d(c, c*2, 3, padding=1), nn.BatchNorm2d(c*2), nn.ReLU(inplace=True), nn.Dropout2d(dropout_rate),
            nn.Conv2d(c*2, c*2, 3, padding=1), nn.BatchNorm2d(c*2), nn.ReLU(inplace=True)
        )
        self.pool2 = nn.MaxPool2d(2)
        
        self.enc3 = nn.Sequential(
            nn.Conv2d(c*2, c*4, 3, padding=1), nn.BatchNorm2d(c*4), nn.ReLU(inplace=True), nn.Dropout2d(dropout_rate),
            nn.Conv2d(c*4, c*4, 3, padding=1), nn.BatchNorm2d(c*4), nn.ReLU(inplace=True)
        )
        self.pool3 = nn.MaxPool2d(2)
        
        # Bottleneck
        self.bottleneck = nn.Sequential(
            nn.Conv2d(c*4, c*8, 3, padding=1), nn.BatchNorm2d(c*8), nn.ReLU(inplace=True), nn.Dropout2d(dropout_rate),
            nn.Conv2d(c*8, c*8, 3, padding=1), nn.BatchNorm2d(c*8), nn.ReLU(inplace=True)
        )
        
        # Decoder
        self.up3 = nn.ConvTranspose2d(c*8, c*4, 2, stride=2)
        self.dec3 = nn.Sequential(
            nn.Conv2d(c*8, c*4, 3, padding=1), nn.BatchNorm2d(c*4), nn.ReLU(inplace=True), nn.Dropout2d(dropout_rate),
            nn.Conv2d(c*4, c*4, 3, padding=1), nn.BatchNorm2d(c*4), nn.ReLU(inplace=True)
        )
        
        self.up2 = nn.ConvTranspose2d(c*4, c*2, 2, stride=2)
        self.dec2 = nn.Sequential(
            nn.Conv2d(c*4, c*2, 3, padding=1), nn.BatchNorm2d(c*2), nn.ReLU(inplace=True), nn.Dropout2d(dropout_rate),
            nn.Conv2d(c*2, c*2, 3, padding=1), nn.BatchNorm2d(c*2), nn.ReLU(inplace=True)
        )
        
        self.up1 = nn.ConvTranspose2d(c*2, c, 2, stride=2)
        self.dec1 = nn.Sequential(
            nn.Conv2d(c*2, c, 3, padding=1), nn.BatchNorm2d(c), nn.ReLU(inplace=True), nn.Dropout2d(dropout_rate),
            nn.Conv2d(c, c, 3, padding=1), nn.BatchNorm2d(c), nn.ReLU(inplace=True)
        )
        
        self.final = nn.Conv2d(c, num_classes, 1)
    
    def forward(self, x, prior):
        # Fuse image + prior: (B,1,H,W) + (B,3,H,W) -> (B,4,H,W)
        x = torch.cat([x, prior], dim=1)
        
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool1(e1))
        e3 = self.enc3(self.pool2(e2))
        b = self.bottleneck(self.pool3(e3))
        
        d3 = self.dec3(torch.cat([self.up3(b), e3], 1))
        d2 = self.dec2(torch.cat([self.up2(d3), e2], 1))
        d1 = self.dec1(torch.cat([self.up1(d2), e1], 1))
        
        return self.final(d1)

model = PriorUNet(num_classes=NUM_CLASSES, dropout_rate=0.3).to(DEVICE)
params = sum(p.numel() for p in model.parameters())
print(f"✅ Model with Dropout: {params:,} parameters")
# Out:
# 🎯 Configuring model for 55 classes
# ✅ Model with Dropout: 1,930,487 parameters

# %%
# Few-shot training loop
print("\n🚀 Few-Shot Training (Optimized for actual classes)\n")

# Focal Loss for imbalanced classes
class FocalLoss(nn.Module):
    def __init__(self, weight=None, gamma=2, reduction='mean'):
        super().__init__()
        self.weight = weight
        self.gamma = gamma
        self.reduction = reduction
        self.ce_loss = nn.CrossEntropyLoss(weight=weight, reduction='none')
    
    def forward(self, logits, targets):
        ce_loss = self.ce_loss(logits, targets)
        p = torch.exp(-ce_loss)
        focal_loss = (1 - p) ** self.gamma * ce_loss
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        return focal_loss

# Compute class weights
class_counts = np.bincount(labels_2d.flatten(), minlength=NUM_CLASSES)
class_weights = torch.tensor(1.0 / (np.sqrt(np.sqrt(class_counts)) + 1), dtype=torch.float32).to(DEVICE)
class_weights = class_weights / class_weights.sum() * NUM_CLASSES

optimizer = torch.optim.Adam(model.parameters(), lr=5e-5, weight_decay=2e-4, betas=(0.9, 0.999))
loss_fn = FocalLoss(weight=class_weights, gamma=2.0)

N_SUPPORT, N_QUERY = 4, 1
N_EPISODES = 100
history = {'s_loss': [], 'q_loss': [], 'q_acc': []}

for ep in range(N_EPISODES):
    # Sample random batch
    ids = np.random.permutation(len(images_np))[:N_SUPPORT + N_QUERY]
    s_ids, q_ids = ids[:N_SUPPORT], ids[N_SUPPORT:]
    
    # SUPPORT PHASE
    model.train()
    s_loss_ep = 0
    for s_id in s_ids:
        img = torch.tensor(images_np[s_id][None, None, :, :], dtype=torch.float32).to(DEVICE)
        lbl = torch.tensor(labels_2d[s_id][None, :, :], dtype=torch.long).to(DEVICE)
        prior = torch.tensor(prior_gen.get_prior(images_np[s_id])[None, :, :, :], dtype=torch.float32).to(DEVICE)
        
        logits = model(img, prior)
        loss = loss_fn(logits, lbl)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        s_loss_ep += loss.item()
    
    s_loss_ep /= len(s_ids)
    
    # QUERY PHASE
    model.eval()
    q_loss_ep = q_acc_ep = 0
    with torch.no_grad():
        for q_id in q_ids:
            img = torch.tensor(images_np[q_id][None, None, :, :], dtype=torch.float32).to(DEVICE)
            lbl = torch.tensor(labels_2d[q_id][None, :, :], dtype=torch.long).to(DEVICE)
            prior = torch.tensor(prior_gen.get_prior(images_np[q_id])[None, :, :, :], dtype=torch.float32).to(DEVICE)
            
            logits = model(img, prior)
            loss = loss_fn(logits, lbl)
            q_loss_ep += loss.item()
            
            pred = torch.argmax(logits, dim=1)[0].cpu().numpy()
            q_acc_ep += (pred == labels_2d[q_id]).mean()
    
    q_loss_ep /= len(q_ids)
    q_acc_ep /= len(q_ids)
    
    history['s_loss'].append(s_loss_ep)
    history['q_loss'].append(q_loss_ep)
    history['q_acc'].append(q_acc_ep)
    
    print(f"Episode {ep+1}/{N_EPISODES} | S.Loss: {s_loss_ep:.4f} | Q.Loss: {q_loss_ep:.4f} | Q.Acc: {q_acc_ep:.2%}")

print("\n✅ Training complete!")
# Out:
# 🚀 Few-Shot Training (Optimized for actual classes)
#
# Episode 1/100 | S.Loss: 0.2634 | Q.Loss: 0.0983 | Q.Acc: 0.00%
# Episode 2/100 | S.Loss: 0.3027 | Q.Loss: 0.1396 | Q.Acc: 0.00%
# Episode 3/100 | S.Loss: 0.2452 | Q.Loss: 0.0923 | Q.Acc: 69.07%
# Episode 4/100 | S.Loss: 0.1523 | Q.Loss: 0.3378 | Q.Acc: 25.74%
# Episode 5/100 | S.Loss: 0.2424 | Q.Loss: 0.0890 | Q.Acc: 48.28%
# Episode 6/100 | S.Loss: 0.3344 | Q.Loss: 0.6676 | Q.Acc: 24.09%
# Episode 7/100 | S.Loss: 0.2355 | Q.Loss: 0.2309 | Q.Acc: 22.61%
# Episode 8/100 | S.Loss: 0.1946 | Q.Loss: 0.0873 | Q.Acc: 2.40%
# Episode 9/100 | S.Loss: 0.1416 | Q.Loss: 0.0877 | Q.Acc: 8.28%
# Episode 10/100 | S.Loss: 0.1809 | Q.Loss: 0.4562 | Q.Acc: 25.41%
# Episode 11/100 | S.Loss: 0.2972 | Q.Loss: 0.2239 | Q.Acc: 28.65%
# Episode 12/100 | S.Loss: 0.1571 | Q.Loss: 0.3341 | Q.Acc: 36.83%
# Episode 77/100 | S.Loss: 0.1134 | Q.Loss: 0.0564 | Q.Acc: 92.23%
# Episode 78/100 | S.Loss: 0.0628 | Q.Loss: 0.0588 | Q.Acc: 87.99%
# Episode 79/100 | S.Loss: 0.3542 | Q.Loss: 0.0593 | Q.Acc: 81.49%
# Episode 80/100 | S.Loss: 0.3241 | Q.Loss: 0.3484 | Q.Acc: 75.73%
# Episode 81/100 | S.Loss: 0.2098 | Q.Loss: 0.0614 | Q.Acc: 87.49%
# Episode 82/100 | S.Loss: 0.3344 | Q.Loss: 0.2012 | Q.Acc: 80.90%
# Episode 83/100 | S.Loss: 0.2220 | Q.Loss: 0.5782 | Q.Acc: 63.20%
# Episode 84/100 | S.Loss: 0.1472 | Q.Loss: 0.0597 | Q.Acc: 87.41%
# Episode 85/100 | S.Loss: 0.1274 | Q.Loss: 0.0614 | Q.Acc: 87.01%
# Episode 86/100 | S.Loss: 0.1737 | Q.Loss: 0.0586 | Q.Acc: 85.66%
# Episode 87/100 | S.Loss: 0.2712 | Q.Loss: 0.0577 | Q.Acc: 92.32%
# Episode 88/100 | S.Loss: 0.1608 | Q.Loss: 0.0614 | Q.Acc: 82.23%
# Episode 89/100 | S.Loss: 0.0785 | Q.Loss: 0.0588 | Q.Acc: 85.50%
# Episode 90/100 | S.Loss: 0.1800 | Q.Loss: 0.0585 | Q.Acc: 91.03%
# Episode 91/100 | S.Loss: 0.0987 | Q.Loss: 0.3224 | Q.Acc: 68.79%
# Episode 92/100 | S.Loss: 0.1836 | Q.Loss: 0.6647 | Q.Acc: 62.83%
# Episode 93/100 | S.Loss: 0.2353 | Q.Loss: 0.1856 | Q.Acc: 76.41%
# Episode 94/100 | S.Loss: 0.2074 | Q.Loss: 0.1006 | Q.Acc: 85.60%
# Episode 95/100 | S.Loss: 0.0965 | Q.Loss: 0.0592 | Q.Acc: 88.42%
# Episode 96/100 | S.Loss: 0.1971 | Q.Loss: 0.2916 | Q.Acc: 77.41%
# Episode 97/100 | S.Loss: 0.2372 | Q.Loss: 0.0620 | Q.Acc: 84.07%
# Episode 98/100 | S.Loss: 0.1864 | Q.Loss: 0.2520 | Q.Acc: 79.66%
# Episode 99/100 | S.Loss: 0.0830 | Q.Loss: 0.1136 | Q.Acc: 90.24%
# Episode 100/100 | S.Loss: 0.1185 | Q.Loss: 0.0562 | Q.Acc: 81.09%
#
# ✅ Training complete!

# %%
# Training history
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].plot(history['s_loss'], marker='o', linewidth=2)
axes[0].set_title('Support Loss')
axes[0].set_ylabel('Loss')
axes[0].grid(True, alpha=0.3)

axes[1].plot(history['q_loss'], marker='s', linewidth=2, color='orange')
axes[1].set_title('Query Loss')
axes[1].set_ylabel('Loss')
axes[1].grid(True, alpha=0.3)

axes[2].plot([x*100 for x in history['q_acc']], marker='^', linewidth=2, color='green')
axes[2].set_title('Query Accuracy')
axes[2].set_ylabel('Accuracy (%)')
axes[2].grid(True, alpha=0.3)

for ax in axes:
    ax.set_xlabel('Episode')

plt.tight_layout()
plt.show()

print(f"Final Accuracy: {history['q_acc'][-1]:.2%}")
# Out:
# Final Accuracy: 81.09%

# %%
# Prediction viewer function
def show_prediction(idx):
    model.eval()
    with torch.no_grad():
        img_t = torch.tensor(images_np[idx][None, None, :, :], dtype=torch.float32).to(DEVICE)
        prior_t = torch.tensor(prior_gen.get_prior(images_np[idx])[None, :, :, :], dtype=torch.float32).to(DEVICE)
        
        logits = model(img_t, prior_t)
        pred = torch.argmax(logits, dim=1)[0].cpu().numpy()
    
    lbl = labels_2d[idx]
    acc = (pred == lbl).mean()
    
    # Calculate Dice score on annotated pixels (non-background, class > 0)
    mask_annotated = lbl > 0  # Assume class 0 is background
    
    dice_scores = []
    if mask_annotated.sum() > 0:
        # Calculate per-class Dice score on annotated pixels
        for cls in np.unique(lbl[mask_annotated]):
            tp = ((pred == cls) & (lbl == cls) & mask_annotated).sum()
            fp = ((pred == cls) & (lbl != cls) & mask_annotated).sum()
            fn = ((pred != cls) & (lbl == cls) & mask_annotated).sum()
            
            if (2*tp + fp + fn) > 0:
                dice = 2*tp / (2*tp + fp + fn)
                dice_scores.append(dice)
        
        # Mean Dice score on annotated pixels
        dice_annotated = np.mean(dice_scores) if dice_scores else 0.0
        acc_annotated = (pred[mask_annotated] == lbl[mask_annotated]).mean()
    else:
        dice_annotated = 0.0
        acc_annotated = 0.0
    
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    axes[0].imshow(images_np[idx], cmap='gray')
    axes[0].set_title('Original Image', fontsize=13, fontweight='bold')
    axes[0].axis('off')
    
    im1 = axes[1].imshow(lbl, cmap='tab20', interpolation='nearest')
    axes[1].set_title('Ground Truth', fontsize=13, fontweight='bold')
    axes[1].axis('off')
    plt.colorbar(im1, ax=axes[1], fraction=0.046)
    
    im2 = axes[2].imshow(pred, cmap='tab20', interpolation='nearest')
    axes[2].set_title(f'Prediction (Dice: {dice_annotated:.2%})', fontsize=13, fontweight='bold')
    axes[2].axis('off')
    plt.colorbar(im2, ax=axes[2], fraction=0.046)
    
    plt.suptitle(f'Image {idx} - Segmentation Results', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    print(f"\nImage {idx}:")
    print(f"  GT classes: {len(np.unique(lbl))}")
    print(f"  Pred classes: {len(np.unique(pred))}")
    print(f"  Pixel Accuracy (all): {acc:.2%}")
    print(f"  Pixel Accuracy (annotated): {acc_annotated:.2%}")
    print(f"  Dice Score (annotated): {dice_annotated:.2%}")

# Show examples
for i in [0, 1, 2]:
    show_prediction(i)
    print()
# Out:
# Image 0:
#   GT classes: 11
#   Pred classes: 31
#   Pixel Accuracy (all): 75.17%
#   Pixel Accuracy (annotated): 0.19%
#   Dice Score (annotated): 0.35%
# Image 1:
#   GT classes: 6
#   Pred classes: 26
#   Pixel Accuracy (all): 84.63%
#   Pixel Accuracy (annotated): 0.43%
#   Dice Score (annotated): 0.36%
# Image 2:
#   GT classes: 2
#   Pred classes: 23
#   Pixel Accuracy (all): 78.05%
#   Pixel Accuracy (annotated): 0.00%
#   Dice Score (annotated): 0.00%

# %% [markdown]
# ## 🎨 Interactive Viewer - Change image index below

# %%
img_idx = 0  # Change to 0-7
show_prediction(img_idx)
# Out:
# Image 0:
#   GT classes: 11
#   Pred classes: 31
#   Pixel Accuracy (all): 75.17%
#   Pixel Accuracy (annotated): 0.19%
#   Dice Score (annotated): 0.35%
